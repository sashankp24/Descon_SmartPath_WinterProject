# %%
import pandas as pd
df=pd.read_csv(r"E:\Milind\Descon\Grades.csv")

# Splitting the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[["Hours Studied","Attendence Percentage"]],df["Final Score"],train_size=0.8,random_state=42)

# Model Training
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(x_train,y_train)

print("cofficients=",model.coef_)
print("intercept=",model.intercept_)

#Mean Sqared Error
from sklearn.metrics import mean_squared_error
y_predicted=model.predict(x_test)
print("MSE=",mean_squared_error(y_test,y_predicted))
# Out:
# cofficients= [-2.43240257  1.56236608]
# intercept= -44.46783346725597
# MSE= 107.08547113679187

# %%
# Read the csv file 
import pandas as pd
df=pd.read_csv(r"E:\Milind\Descon\Grades1.csv")
stats=df.describe()
print(stats)

# histogram to display all the data 
import matplotlib.pyplot as plt
df.hist(figsize=(14,8)   ,linewidth=2,
    edgecolor='black',
    color='skyblue')#**
plt.show()

x=df.drop(df[["Pass_Class"]],axis=1)#features
y=df.Pass_Class#target(0,1)->logistic regression

# Data Splitting
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[["Quiz_Average (0–100)","Time_Spent_Minutes (Daily Avg)","Problems_Solved (Total)"]],df["Pass_Class"],test_size=0.2,random_state=42)

# Model Traing
from sklearn import linear_model
model=linear_model.LogisticRegression()
model.fit(x_train,y_train)

# Evation of the trained data 
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,ConfusionMatrixDisplay

y_predicted=model.predict(x_test)

print("acuraccy=",accuracy_score(y_test,y_predicted))
print("precision=",precision_score(y_test,y_predicted))
print("recall=",recall_score(y_test,y_predicted))
print("f1 score=",f1_score(y_test,y_predicted))
print("confusion matrix: ",confusion_matrix(y_test,y_predicted))
ConfusionMatrixDisplay.from_predictions(y_test,y_predicted)
# Out:
#        Quiz_Average (0–100)  Time_Spent_Minutes (Daily Avg)  \
# count             20.000000                       20.000000
# mean              65.700000                       54.400000
# std               17.137524                       20.967142
# min               40.000000                       20.000000
# 25%               49.500000                       37.250000
# 50%               66.500000                       53.500000
# 75%               80.500000                       71.250000
# max               92.000000                       90.000000
#
#        Problems_Solved (Total)  Pass_Class
# count                20.000000   20.000000
# mean                243.500000    0.550000
# std                 104.202485    0.510418
# min                  90.000000    0.000000
# 25%                 161.250000    0.000000
# 50%                 232.500000    1.000000
# 75%                 316.250000    1.000000
# max                 430.000000    1.000000
# acuraccy= 1.0
# precision= 1.0
# recall= 1.0
# f1 score= 1.0
# confusion matrix:  [[2 0]
#  [0 2]]
