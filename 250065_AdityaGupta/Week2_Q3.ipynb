# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# Importing the dataset

# %%
df = pd.read_hdf("METR-LA.h5")
df = df.dropna()
df.head()
# Out:
#                         773869     767541     767542     717447     717446  \
# 2012-03-01 00:00:00  64.375000  67.625000  67.125000  61.500000  66.875000
# 2012-03-01 00:05:00  62.666667  68.555556  65.444444  62.444444  64.444444
# 2012-03-01 00:10:00  64.000000  63.750000  60.000000  59.000000  66.500000
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000000
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000000
#
#                         717445  773062  767620     737529     717816  ...  \
# 2012-03-01 00:00:00  68.750000  65.125  67.125  59.625000  62.750000  ...
# 2012-03-01 00:05:00  68.111111  65.000  65.000  57.444444  63.333333  ...
# 2012-03-01 00:10:00  66.250000  64.500  64.250  63.875000  65.375000  ...
# 2012-03-01 00:15:00   0.000000   0.000   0.000   0.000000   0.000000  ...
# 2012-03-01 00:20:00   0.000000   0.000   0.000   0.000000   0.000000  ...
#
# ...

# %%
#to convert to kmph
df = df * 1.60934 

#basically the main error is because the sensor reading 0 as no car is passing through
low_speed_mask = df < 2
df[low_speed_mask] = np.nan
df = df.ffill().bfill()

# %%
num_timesteps = len(df)
time_index = np.arange(num_timesteps)
time_of_day = ((time_index * 5) % (24*60)) / (24*60)
day_of_week = ((time_index * 5 // (60 * 24)) + 4) % 7
avg_speed = df.mean(axis=1)

# %% [markdown]
# Splitting the Data Set:

# %%
X = pd.DataFrame({
    "time_of_day": time_of_day,
    "day_of_week": day_of_week
})

y = avg_speed
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15
)

# %% [markdown]
# Training the model:

# %%
model = RandomForestRegressor(
    n_estimators=200,
    max_depth=15,
)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=15, n_estimators=200)

# %% [markdown]
# Predictions and calculating the MAE

# %%
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 2.6406296271875984
# RMSE: 4.223898388625066

# %%
plt.plot(y_test.values[:50], label="Actual Speed")
plt.plot(y_pred[:50], label="Predicted Speed")
plt.xlabel("Time Steps")
plt.ylabel("Average Speed")
plt.legend()
plt.title("Actual vs Predicted Speed")
plt.show()

# %% [markdown]
# Total time prediction:

# %%
def predict_speed(hour, minute, day_of_week):
    time_frac = (hour * 60 + minute) / (24 * 60)
    
    X_input = pd.DataFrame([{
        "time_of_day": time_frac,
        "day_of_week": day_of_week
    }])
    
    return model.predict(X_input)[0]

def estimate_travel_time(distance_km, speed_kmh):
    return (distance_km / speed_kmh) * 60

# %%
hour = 22
minutes = 20 
day = 7         
distance = 12   

pred_speed = predict_speed(hour, minutes, day)
travel_time = estimate_travel_time(distance, pred_speed)

print("Predicted Speed (km/h):", round(pred_speed, 2))
print("Estimated Travel Time (minutes):", round(travel_time, 2))
# Out:
# Predicted Speed (km/h): 99.12
# Estimated Travel Time (minutes): 7.26
